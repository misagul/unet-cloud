# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
# %cd drive/MyDrive/cloud-dataset
# Out:
# /content/drive/MyDrive/cloud-dataset

# %%
# !pip install tf-nightly

# %%
# !unzip drive/MyDrive/cloud-dataset/train_gt.zip -d train_gt

# %% [markdown]
# # TRAIN

# %%
import os
import numpy as np
import cv2
from glob import glob
import tensorflow as tf
import keras.backend as K
from keras.layers import Conv2D, BatchNormalization, Activation, MaxPool2D, Conv2DTranspose, Concatenate, Input
from keras.models import Model
from keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau, CSVLogger

os.environ["PYTHONHASHSEED"] = str(42)
np.random.seed(42)
tf.random.set_seed(42)

# %%
lr = 1e-4
height = 384
width = 384
files_dir = os.path.join("files")
model_file = os.path.join(files_dir, "unet-checkpoint.h5")
log_file = os.path.join(files_dir, "log.csv")

def conv_block(inputs, num_filters):
    x = Conv2D(num_filters, 3, padding="same")(inputs)
    x = BatchNormalization()(x)
    x = Activation("relu")(x)

    x = Conv2D(num_filters, 3, padding="same")(x)
    x = BatchNormalization()(x)
    x = Activation("relu")(x)

    return x

def encoder_block(inputs, num_filters):
    x = conv_block(inputs, num_filters)
    p = MaxPool2D((2,2))(x)
    return x, p

def decoder_block(inputs, skip, num_filters):
    x = Conv2DTranspose(num_filters, (2,2), strides=2, padding="same")(inputs)
    x = Concatenate()([x, skip])
    x = conv_block(x, num_filters)
    return x

def build_unet(input_shape):
    inputs = Input(input_shape)

    s1, p1 = encoder_block(inputs, 64)
    s2, p2 = encoder_block(p1, 128)
    s3, p3 = encoder_block(p2, 256)
    s4, p4 = encoder_block(p3, 512)

    b1 = conv_block(p4, 512)

    d1 = decoder_block(b1, s4, 512)
    d2 = decoder_block(d1, s3, 256)
    d3 = decoder_block(d2, s2, 128)
    d4 = decoder_block(d3, s1, 64)

    outputs = Conv2D(1, 1, padding="same", activation="sigmoid")(d4)

    model = Model(inputs, outputs, name="UNET")
    return model

def load_data(train_count, val_count):
    train_x = sorted(glob(os.path.join("train_blue", "*")))[:train_count]
    train_y = sorted(glob(os.path.join("train_gt", "*")))[:train_count]

    valid_x = sorted(glob(os.path.join("train_blue", "*")))[train_count:train_count+val_count]
    valid_y = sorted(glob(os.path.join("train_gt", "*")))[train_count:train_count+val_count]

    return (train_x, train_y), (valid_x, valid_y)

def read_image(path):
    path = path.decode()
    x = cv2.imread(path, cv2.IMREAD_COLOR)
    x = x/255.0
    return x

def read_mask(path):
    path = path.decode()
    x = cv2.imread(path, cv2.IMREAD_GRAYSCALE)
    x = x/255.0
    x = np.expand_dims(x, axis=-1)
    return x

def tf_parse(x, y):
    def _parse(x, y):
        x = read_image(x)
        y = read_mask(y)
        return x, y

    x, y = tf.numpy_function(_parse, [x, y], [tf.float64, tf.float64])
    x.set_shape([height, width, 3])
    y.set_shape([height, width, 1])

    return x, y

def tf_dataset(x, y, batch=1):
    dataset = tf.data.Dataset.from_tensor_slices((x,y))
    dataset = dataset.map(tf_parse, num_parallel_calls=tf.data.AUTOTUNE)
    dataset = dataset.batch(batch)
    dataset = dataset.prefetch(tf.data.AUTOTUNE)
    return dataset

input_shape = (height, width, 3)

callbacks= [
    ModelCheckpoint(model_file, verbose=1, save_best_only=True),
    ReduceLROnPlateau(monitor="val_loss", factor=0.1, patience=4),
    CSVLogger(log_file),
    EarlyStopping(monitor="val_loss", patience=20, restore_best_weights=False)
]

def recall_m(y_true, y_pred):
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
    recall = true_positives / (possible_positives + K.epsilon())
    return recall

def precision_m(y_true, y_pred):
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
    precision = true_positives / (predicted_positives + K.epsilon())
    return precision

def f1_m(y_true, y_pred):
    precision = precision_m(y_true, y_pred)
    recall = recall_m(y_true, y_pred)
    return 2*((precision*recall)/(precision+recall+K.epsilon()))

binary_iou = tf.keras.metrics.BinaryIoU(name='IoU')
recall = tf.keras.metrics.Recall()
precision = tf.keras.metrics.Precision()

# %%
epochs = 30
batch_size = 2
train_count = 1000
val_count = 300

# %%
(train_x, train_y), (valid_x, valid_y) = load_data(train_count, val_count)
train_dataset = tf_dataset(train_x, train_y, batch=batch_size)
valid_dataset = tf_dataset(valid_x, valid_y, batch=batch_size)

print(f"Train: {len(train_dataset)}, Valid: {len(valid_dataset)}")

model = build_unet(input_shape)
opt = tf.keras.optimizers.Adam(lr)
model.compile(loss="binary_crossentropy", optimizer=opt, metrics=["acc", binary_iou, recall, precision])

model.fit(
    train_dataset,
    validation_data=valid_dataset,
    epochs=epochs,
    callbacks=callbacks,

)
# Out:
# Train: 500, Valid: 150
# Epoch 1/30
# 500/500 [==============================] - ETA: 0s - loss: 0.4755 - acc: 0.7984 - IoU: 0.6318 - recall: 0.6536 - precision: 0.7220
# Epoch 1: val_loss improved from 0.69080 to 0.48347, saving model to files/unet-checkpoint.h5
# 500/500 [==============================] - 361s 700ms/step - loss: 0.4755 - acc: 0.7984 - IoU: 0.6318 - recall: 0.6536 - precision: 0.7220 - val_loss: 0.4835 - val_acc: 0.7187 - val_IoU: 0.5609 - val_recall: 0.9723 - val_precision: 0.5741 - lr: 1.0000e-04
# Epoch 2/30
# 500/500 [==============================] - ETA: 0s - loss: 0.3946 - acc: 0.8284 - IoU: 0.6804 - recall: 0.7264 - precision: 0.7552
# Epoch 2: val_loss improved from 0.48347 to 0.41800, saving model to files/unet-checkpoint.h5
# 500/500 [==============================] - 539s 1s/step - loss: 0.3946 - acc: 0.8284 - IoU: 0.6804 - recall: 0.7264 - precision: 0.7552 - val_loss: 0.4180 - val_acc: 0.7881 - val_IoU: 0.6483 - val_recall: 0.9274 - val_precision: 0.6535 - lr: 1.0000e-04
# Epoch 3/30
# 500/500 [==============================] - ETA: 0s - loss: 0.3588 - acc: 0.8471 - IoU: 0.7100 - recall: 0.7568 - precision: 0.7825
# Epoch 3: val_loss did not improve from 0.41800
# 500/500 [==============================] - 156s 311ms/step - loss: 0.3588 - acc: 0.8471 - IoU: 0.7100 - recall: 0.7568 - precision: 0.7825 - val_loss: 0.6274 - val_acc: 0.6516 - val_IoU: 0.4455 - val_recall: 0.3990 - val_precision: 0.5499 - lr: 1.0000e-04
# Epoch 4/30
# 500/500 [==============================] - ETA: 0s - loss: 0.3139 - acc: 0.8672 - IoU: 0.7421 - recall: 0.7794 - precision: 0.8181
# Epoch 4: val_loss did not improve from 0.41800
# 500/500 [==============================] - 152s 304ms/step - loss: 0.3139 - acc: 0.8672 - IoU: 0.7421 - recall: 0.7794 - precision: 0.8181 - val_loss: 0.5045 - val_acc: 0.6818 - val_IoU: 0.4668 - val_recall: 0.3680 - val_precision: 0.6309 - lr: 1.0000e-04
# Epoch 5/30
# 500/500 [==============================] - ETA: 0s - loss: 0.2885 - acc: 0.8776 - IoU: 0.7597 - recall: 0.7949 - precision: 0.8343
# Epoch 5: val_loss did not improve from 0.41800
# 500/500 [==============================] - 150s 300ms/step - loss: 0.2885 - acc: 0.8776 - IoU: 0.7597 - recall: 0.7949 - precision: 0.8343 - val_loss: 0.5966 - val_acc: 0.6483 - val_IoU: 0.4103 - val_recall: 0.2461 - val_precision: 0.5742 - lr: 1.0000e-04
# Epoch 6/30
# 500/500 [==============================] - ETA: 0s - loss: 0.2879 - acc: 0.8759 - IoU: 0.7566 - recall: 0.7909 - precision: 0.8325
# Epoch 6: val_loss did not improve from 0.41800
# 500/500 [==============================] - 159s 319ms/step - loss: 0.2879 - acc: 0.8759 - IoU: 0.7566 - recall: 0.7909 - precision: 0.8325 - val_loss: 0.5423 - val_acc: 0.6858 - val_IoU: 0.4790 - val_recall: 0.4115 - val_precision: 0.6238 - lr: 1.0000e-04
# Epoch 7/30
# 500/500 [==============================] - ETA: 0s - loss: 0.2393 - acc: 0.9095 - IoU: 0.8173 - recall: 0.8598 - precision: 0.8701
# Epoch 7: val_loss improved from 0.41800 to 0.37316, saving model to files/unet-checkpoint.h5
# 500/500 [==============================] - 160s 319ms/step - loss: 0.2393 - acc: 0.9095 - IoU: 0.8173 - recall: 0.8598 - precision: 0.8701 - val_loss: 0.3732 - val_acc: 0.8161 - val_IoU: 0.6846 - val_recall: 0.8916 - val_precision: 0.7005 - lr: 1.0000e-05
# Epoch 8/30
# 500/500 [==============================] - ETA: 0s - loss: 0.2226 
30
# 500/500 [==============================] - ETA: 0s - loss: 0.1863 - acc: 0.9373 - IoU: 0.8692 - recall: 0.8983 - precision: 0.9142
# Epoch 29: val_loss did not improve from 0.37076
# 500/500 [==============================] - 157s 313ms/step - loss: 0.1863 - acc: 0.9373 - IoU: 0.8692 - recall: 0.8983 - precision: 0.9142 - val_loss: 0.3747 - val_acc: 0.8127 - val_IoU: 0.6747 - val_recall: 0.8080 - val_precision: 0.7248 - lr: 1.0000e-09
# Epoch 30/30
# 500/500 [==============================] - ETA: 0s - loss: 0.1863 - acc: 0.9373 - IoU: 0.8692 - recall: 0.8983 - precision: 0.9142
# Epoch 30: val_loss did not improve from 0.37076
# 500/500 [==============================] - 153s 306ms/step - loss: 0.1863 - acc: 0.9373 - IoU: 0.8692 - recall: 0.8983 - precision: 0.9142 - val_loss: 0.3747 - val_acc: 0.8127 - val_IoU: 0.6747 - val_recall: 0.8080 - val_precision: 0.7248 - lr: 1.0000e-09

# %%
epochs = 30
batch_size = 4      # before: 2
train_count = 1000
val_count = 300

# %%
(train_x, train_y), (valid_x, valid_y) = load_data(train_count, val_count)
train_dataset = tf_dataset(train_x, train_y, batch=batch_size)
valid_dataset = tf_dataset(valid_x, valid_y, batch=batch_size)

print(f"Train: {len(train_dataset)}, Valid: {len(valid_dataset)}")

model = build_unet(input_shape)
opt = tf.keras.optimizers.Adam(lr)
model.compile(loss="binary_crossentropy", optimizer=opt, metrics=["acc", binary_iou, precision, recall])

model.fit(
    train_dataset,
    validation_data=valid_dataset,
    epochs=epochs,
    callbacks=callbacks
)
# Out:
# Train: 250, Valid: 75
# Epoch 1/30
# 250/250 [==============================] - ETA: 0s - loss: 0.5355 - acc: 0.7722 - IoU: 0.6087 - precision: 0.6234 - recall: 0.7682
# Epoch 1: val_loss improved from inf to 0.73182, saving model to files/unet-checkpoint.h5
# 250/250 [==============================] - 311s 1s/step - loss: 0.5355 - acc: 0.7722 - IoU: 0.6087 - precision: 0.6234 - recall: 0.7682 - val_loss: 0.7318 - val_acc: 0.4466 - val_IoU: 0.2590 - val_precision: 0.4043 - val_recall: 0.9999 - lr: 1.0000e-04
# Epoch 2/30
# 250/250 [==============================] - ETA: 0s - loss: 0.4633 - acc: 0.8120 - IoU: 0.6612 - precision: 0.7086 - recall: 0.7515
# Epoch 2: val_loss improved from 0.73182 to 0.59046, saving model to files/unet-checkpoint.h5
# 250/250 [==============================] - 151s 604ms/step - loss: 0.4633 - acc: 0.8120 - IoU: 0.6612 - precision: 0.7086 - recall: 0.7515 - val_loss: 0.5905 - val_acc: 0.6388 - val_IoU: 0.4657 - val_precision: 0.5097 - val_recall: 0.9980 - lr: 1.0000e-04
# Epoch 3/30
# 250/250 [==============================] - ETA: 0s - loss: 0.4311 - acc: 0.8281 - IoU: 0.6831 - precision: 0.7409 - recall: 0.7538
# Epoch 3: val_loss improved from 0.59046 to 0.43158, saving model to files/unet-checkpoint.h5
# 250/250 [==============================] - 150s 601ms/step - loss: 0.4311 - acc: 0.8281 - IoU: 0.6831 - precision: 0.7409 - recall: 0.7538 - val_loss: 0.4316 - val_acc: 0.7628 - val_IoU: 0.6151 - val_precision: 0.6266 - val_recall: 0.9119 - lr: 1.0000e-04
# Epoch 4/30
# 250/250 [==============================] - ETA: 0s - loss: 0.3980 - acc: 0.8455 - IoU: 0.7089 - precision: 0.7723 - recall: 0.7680
# 250/250 [==============================] - 161s 643ms/step - loss: 0.1297 - acc: 0.9597 - IoU: 0.9136 - precision: 0.9485 - recall: 0.9309 - val_loss: 0.2418 - val_acc: 0.8944 - val_IoU: 0.8022 - val_precision: 0.8218 - val_recall: 0.9179 - lr: 1.0000e-05
# Epoch 28/30
# 250/250 [==============================] - ETA: 0s - loss: 0.1268 - acc: 0.9607 - IoU: 0.9158 - precision: 0.9500 - recall: 0.9326
# Epoch 28: val_loss improved from 0.24179 to 0.23868, saving model to files/unet-checkpoint.h5
# 250/250 [==============================] - 159s 637ms/step - loss: 0.1268 - acc: 0.9607 - IoU: 0.9158 - precision: 0.9500 - recall: 0.9326 - val_loss: 0.2387 - val_acc: 0.8958 - val_IoU: 0.8041 - val_precision: 0.8284 - val_recall: 0.9114 - lr: 1.0000e-05
# Epoch 29/30
# 250/250 [==============================] - ETA: 0s - loss: 0.1243 - acc: 0.9615 - IoU: 0.9175 - precision: 0.9509 - recall: 0.9341
# Epoch 29: val_loss improved from 0.23868 to 0.23671, saving model to files/unet-checkpoint.h5
# 250/250 [==============================] - 160s 639ms/step - loss: 0.1243 - acc: 0.9615 - IoU: 0.9175 - precision: 0.9509 - recall: 0.9341 - val_loss: 0.2367 - val_acc: 0.8970 - val_IoU: 0.8060 - val_precision: 0.8308 - val_recall: 0.9113 - lr: 1.0000e-05
# Epoch 30/30
# 250/250 [==============================] - ETA: 0s - loss: 0.1223 - acc: 0.9621 - IoU: 0.9186 - precision: 0.9513 - recall: 0.9354
# Epoch 30: val_loss improved from 0.23671 to 0.23525, saving model to files/unet-checkpoint.h5
# 250/250 [==============================] - 157s 628ms/step - loss: 0.1223 - acc: 0.9621 - IoU: 0.9186 - precision: 0.9513 - recall: 0.9354 - val_loss: 0.2352 - val_acc: 0.8996 - val_IoU: 0.8106 - val_precision: 0.8318 - val_recall: 0.9183 - lr: 1.0000e-05

# %%
epochs = 30
batch_size = 2
train_count = 2000  # before: 1000
val_count = 600     # before: 300

# %%
(train_x, train_y), (valid_x, valid_y) = load_data(train_count, val_count)
train_dataset = tf_dataset(train_x, train_y, batch=batch_size)
valid_dataset = tf_dataset(valid_x, valid_y, batch=batch_size)

print(f"Train: {len(train_dataset)}, Valid: {len(valid_dataset)}")

model = build_unet(input_shape)
opt = tf.keras.optimizers.Adam(lr)
model.compile(loss="binary_crossentropy", optimizer=opt, metrics=["acc", binary_iou, precision, recall])

model.fit(
    train_dataset,
    validation_data=valid_dataset,
    epochs=epochs,
    callbacks=callbacks
)
# Out:
# Train: 1000, Valid: 300
# Epoch 1/30
# 1000/1000 [==============================] - ETA: 0s - loss: 0.4353 - acc: 0.8105 - IoU: 0.6822 - precision: 0.7452 - recall: 0.7734
# Epoch 1: val_loss did not improve from 0.23525
# 1000/1000 [==============================] - 496s 482ms/step - loss: 0.4353 - acc: 0.8105 - IoU: 0.6822 - precision: 0.7452 - recall: 0.7734 - val_loss: 0.4517 - val_acc: 0.7840 - val_IoU: 0.6194 - val_precision: 0.7780 - val_recall: 0.6122 - lr: 1.0000e-04
# Epoch 2/30
# 1000/1000 [==============================] - ETA: 0s - loss: 0.3358 - acc: 0.8555 - IoU: 0.7308 - precision: 0.8047 - recall: 0.7910
# Epoch 2: val_loss did not improve from 0.23525
# 1000/1000 [==============================] -
_dataset = tf_dataset(train_x, train_y, batch=batch_size)
valid_dataset = tf_dataset(valid_x, valid_y, batch=batch_size)

print(f"Train: {len(train_dataset)}, Valid: {len(valid_dataset)}")

model = build_unet(input_shape)
opt = tf.keras.optimizers.Adam(lr)
model.compile(loss="binary_crossentropy", optimizer=opt, metrics=["acc", binary_iou, precision, recall])

model.fit(
    train_dataset,
    validation_data=valid_dataset,
    epochs=epochs,
    callbacks=callbacks
)
# Out:
# 8400
# train_blue/blue_patch_100_5_by_12_LC08_L1TP_061017_20160720_20170223_01_T1.TIF 2000
# Train: 500, Valid: 150
# Epoch 1/30
# 500/500 [==============================] - ETA: 0s - loss: 0.4348 - acc: 0.8158 - IoU: 0.6681 - precision: 0.7568 - recall: 0.7202
# Epoch 1: val_loss improved from inf to 0.45926, saving model to files/unet-checkpoint.h5
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3086: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 500/500 [==============================] - 364s 650ms/step - loss: 0.4348 - acc: 0.8158 - IoU: 0.6681 - precision: 0.7568 - recall: 0.7202 - val_loss: 0.4593 - val_acc: 0.7409 - val_IoU: 0.5884 - val_precision: 0.5990 - val_recall: 0.9842 - lr: 1.0000e-04
# Epoch 2/30
# 500/500 [==============================] - ETA: 0s - loss: 0.3679 - acc: 0.8421 - IoU: 0.7096 - precision: 0.7864 - recall: 0.7714
# Epoch 2: val_loss improved from 0.45926 to 0.34159, saving model to files/unet-checkpoint.h5
# 500/500 [==============================] - 324s 647ms/step - loss: 0.3679 - acc: 0.8421 - IoU: 0.7096 - precision: 0.7864 - recall: 0.7714 - val_loss: 0.3416 - val_acc: 0.8173 - val_IoU: 0.6890 - val_precision: 0.6937 - val_recall: 0.9389 - lr: 1.0000e-04
# Epoch 3/30
# 500/500 [==============================] - ETA: 0s - loss: 0.3329 - acc: 0.8568 - IoU: 0.7331 - precision: 0.8044 - recall: 0.7962
# Epoch 3: val_loss did not improve from 0.34159
# 500/500 [==============================] - 323s 646ms/step - loss: 0.3329 - acc: 0.8568 - IoU: 0.7331 - precision: 0.8044 - recall: 0.7962 - val_loss: 0.3502 - val_acc: 0.8380 - val_IoU: 0.7125 - val_precision: 0.7684 - val_recall: 0.8277 - lr: 1.0000e-04
# Epoch 4/30
# 500/500 [==============================] - ETA: 0s - loss: 0.3088 - acc: 0.8679 - IoU: 0.7507 - precision: 0.8219 - recall: 0.8085
# Epoch 4: val_loss improved from 0.34159 to 0.33408, saving model to files/unet-checkpoint.h5
# 500/500 [==============================] - 324s 648ms/step - loss: 0.3088 - acc: 0.8679 - IoU: 0.7507 - precision: 0.8219 - recall: 0.8085 - val_loss: 0.3341 - val_acc: 0.8378 - val_IoU: 0.7109 - val_precision: 0.7773 - val_recall: 0.8096 - lr: 1.0000e-04
# Epoch 5/30
# 500/500 [==============================] - ETA: 0s - loss: 0.2869 - acc: 0.8787 - IoU: 0.7686 - precision: 0.8381 - recall: 0.8223
# Epoch 5: val_loss improved from 0.33408 to 0.32738, saving model to files/unet-checkpoint.h5
# 500/500 [==============================] -
30
# 500/500 [==============================] - ETA: 0s - loss: 0.1155 - acc: 0.9603 - IoU: 0.9175 - precision: 0.9529 - recall: 0.9362
# Epoch 26: val_loss did not improve from 0.18489
# 500/500 [==============================] - 323s 647ms/step - loss: 0.1155 - acc: 0.9603 - IoU: 0.9175 - precision: 0.9529 - recall: 0.9362 - val_loss: 0.1854 - val_acc: 0.9401 - val_IoU: 0.8806 - val_precision: 0.9362 - val_recall: 0.9058 - lr: 1.0000e-05
# Epoch 27/30
# 500/500 [==============================] - ETA: 0s - loss: 0.1128 - acc: 0.9613 - IoU: 0.9194 - precision: 0.9540 - recall: 0.9377
# Epoch 27: val_loss did not improve from 0.18489
# 500/500 [==============================] - 312s 623ms/step - loss: 0.1128 - acc: 0.9613 - IoU: 0.9194 - precision: 0.9540 - recall: 0.9377 - val_loss: 0.1863 - val_acc: 0.9399 - val_IoU: 0.8803 - val_precision: 0.9361 - val_recall: 0.9053 - lr: 1.0000e-05
# Epoch 28/30
# 500/500 [==============================] - ETA: 0s - loss: 0.1105 - acc: 0.9620 - IoU: 0.9209 - precision: 0.9549 - recall: 0.9389
# Epoch 28: val_loss improved from 0.18489 to 0.18423, saving model to files/unet-checkpoint.h5
# 500/500 [==============================] - 329s 658ms/step - loss: 0.1105 - acc: 0.9620 - IoU: 0.9209 - precision: 0.9549 - recall: 0.9389 - val_loss: 0.1842 - val_acc: 0.9409 - val_IoU: 0.8823 - val_precision: 0.9337 - val_recall: 0.9108 - lr: 1.0000e-05
# Epoch 29/30
# 500/500 [==============================] - ETA: 0s - loss: 0.1085 - acc: 0.9627 - IoU: 0.9222 - precision: 0.9554 - recall: 0.9403
# Epoch 29: val_loss did not improve from 0.18423
# 500/500 [==============================] - 324s 648ms/step - loss: 0.1085 - acc: 0.9627 - IoU: 0.9222 - precision: 0.9554 - recall: 0.9403 - val_loss: 0.1853 - val_acc: 0.9411 - val_IoU: 0.8826 - val_precision: 0.9363 - val_recall: 0.9084 - lr: 1.0000e-05
# Epoch 30/30
# 500/500 [==============================] - ETA: 0s - loss: 0.1062 - acc: 0.9635 - IoU: 0.9237 - precision: 0.9563 - recall: 0.9416
# Epoch 30: val_loss did not improve from 0.18423
# 500/500 [==============================] - 323s 647ms/step - loss: 0.1062 - acc: 0.9635 - IoU: 0.9237 - precision: 0.9563 - recall: 0.9416 - val_loss: 0.1853 - val_acc: 0.9404 - val_IoU: 0.8812 - val_precision: 0.9372 - val_recall: 0.9056 - lr: 1.0000e-05

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

accs = [0,0.7943, 0.8199, 0.8347, 0.8591, 0.8843, 0.8966, 0.9081, 0.9123, 0.9170, 0.9278, 0.9359, 0.9442, 0.9471, 0.9495, 0.9515, 0.9533, 0.9549, 0.9562, 0.9573, 0.9582, 0.9592, 0.9601, 0.9611, 0.9621, 0.9630, 0.9642, 0.9658, 0.9663, 0.9665, 0.9667]
epochs = list(range(0,31))

plt.figure(figsize=(15,8))
plt.margins(x=0)
plt.xticks(epochs)
plt.plot(epochs, accs, "--bo")
plt.title('Döngü Sayısı ve Doğruluk Oranı İlişkisi')
plt.xlabel('Döngü Sayısı')
plt.ylabel('Doğruluk Oranı')

plt.show()

# %% [markdown]
# # PREDICT

# %%
import os
import time
import numpy as np
import cv2
from glob import glob
from tqdm import tqdm
import tensorflow as tf
from google.colab.patches import cv2_imshow

os.environ["PYTHONHASHSEED"] = str(42)
np.random.seed(42)
tf.random.set_seed(42)

# %matplotlib inline

# %%
height = 384
width = 384
total = height*width
model_path = "files/unet-checkpoint.h5"
model = tf.keras.models.load_model(model_path)
save_path = "predict/"
train_blue = sorted(glob(os.path.join("train_blue", "*")))
train_gt = sorted(glob(os.path.join("train_gt", "*")))

print(train_gt[:20])
# Out:
# ['train_gt/gt_patch_100_5_by_12_LC08_L1TP_061017_20160720_20170223_01_T1.TIF', 'train_gt/gt_patch_100_5_by_12_LC08_L1TP_063016_20160920_20170221_01_T1.TIF', 'train_gt/gt_patch_100_5_by_12_LC08_L1TP_064014_20160420_20170223_01_T1.TIF', 'train_gt/gt_patch_100_5_by_12_LC08_L1TP_064017_20160420_20170223_01_T1.TIF', 'train_gt/gt_patch_100_5_by_12_LC08_L1TP_066017_20160520_20170223_01_T1.TIF', 'train_gt/gt_patch_100_5_by_16_LC08_L1TP_011247_20160620_20170323_01_T1.TIF', 'train_gt/gt_patch_100_5_by_16_LC08_L1TP_029040_20160720_20170222_01_T1.TIF', 'train_gt/gt_patch_100_5_by_16_LC08_L1TP_032029_20160420_20170223_01_T1.TIF', 'train_gt/gt_patch_100_5_by_16_LC08_L1TP_034034_20160520_20170223_01_T1.TIF', 'train_gt/gt_patch_100_5_by_16_LC08_L1TP_045026_20160720_20170221_01_T1.TIF', 'train_gt/gt_patch_100_5_by_16_LC08_L1TP_047023_20160920_20170221_01_T1.TIF', 'train_gt/gt_patch_100_5_by_20_LC08_L1TP_002053_20160520_20170324_01_T1.TIF', 'train_gt/gt_patch_100_5_by_20_LC08_L1TP_002054_20160520_20170324_01_T1.TIF', 'train_gt/gt_patch_100_5_by_20_LC08_L1TP_035034_20160120_20170224_01_T1.TIF', 'train_gt/gt_patch_100_5_by_20_LC08_L1TP_039034_20160320_20170224_01_T1.TIF', 'train_gt/gt_patch_100_5_by_4_LC08_L1TP_011002_20160620_20170323_01_T1.TIF', 'train_gt/gt_patch_100_5_by_8_LC08_L1TP_044010_20160220_20170224_01_T1.TIF', 'train_gt/gt_patch_100_5_by_8_LC08_L1TP_059014_20160620_20170221_01_T1.TIF', 'train_gt/gt_patch_101_5_by_13_LC08_L1TP_061017_20160720_20170223_01_T1.TIF', 'train_gt/gt_patch_101_5_by_13_LC08_L1TP_063016_20160920_20170221_01_T1.TIF']

# %% [markdown]
# ### Colors

# %%
line = np.full((height,5,3), [255,0,0])

l_red = np.array([217, 136, 128])
l_green = np.array([130, 224, 170])

d_red = np.array([100, 30, 22])
d_green = np.array([20, 90, 50])

red = np.array([255, 0, 0])
green = np.array([0, 255, 0])

white = np.array([255, 255, 255])
black = np.array([0, 0, 0])

# %%
def colored_res(g, p):
    new = np.zeros([384,384,3], dtype=int)
    total = 384*384
    cloud_correct = 0
    cloud_mistake = 0
    not_cloud_correct = 0
    not_cloud_mistake = 0

    for i in range(0,384):
        for j in range(0,384):
            if np.array_equal(g[i][j], white):
                if np.array_equal(p[i][j], white):
                    new[i][j] = l_green
                    cloud_correct += 1
                else:
                    new[i][j] = d_green
                    cloud_mistake += 1
            else:
                if np.array_equal(p[i][j], black):
                    new[i][j] = l_red
                    not_cloud_correct += 1
                else:
                    new[i][j] = d_red
                    not_cloud_mistake += 1
    return new, cloud_correct, cloud_mistake, not_cloud_correct, not_cloud_mistake

# %% [markdown]
# ## Good Results

# %%
test_index = [3391, 3280, 3544, 3300, 3298, 3111, 3316, 3363, 3352, 3281]

blue_test = []
gt_test = []

for i in test_index:
    blue_test.append(train_blue[i])
    gt_test.append(train_gt[i])

# %%
time_taken = []
i = 0
for im in blue_test:
    name = f"{i}.png"
    x = cv2.imread(im, cv2.IMREAD_COLOR)
    x = x/255.0
    x = np.expand_dims(x, axis=0)

    start_time = time.time()
    p = model.predict(x)[0]
    total_time = time.time()-start_time
    time_taken.append(total_time)

    p = p>0.5
    p = p*255.0

    # cv2.imwrite(f"{save_path}/p-{name}", p)
    b = cv2.imread(train_blue[test_index[i]])
    g = cv2.imread(train_gt[test_index[i]])
    bl = np.concatenate((b,line), axis=1)
    f = np.concatenate((bl,g), axis= 1)
    fl = np.concatenate((f,line), axis= 1)
    p = np.dstack([p,p,p])

    f2 = np.concatenate((fl,p), axis= 1)
    f2l = np.concatenate((f2,line), axis= 1)
    res, cloud_correct, cloud_mistake, not_cloud_correct, not_cloud_mistake = colored_res(g, p)
    res2 = res[...,::-1].copy()
    # cv2.imwrite(f"{save_path}/c-{name}", res2)
    final =  np.concatenate((f2l, res), axis= 1)
    final = final[...,::-1].copy()
    cv2_imshow(final)
    print(f"""
        {blue_test[i]}
        Total:\t\t\t{total}
        Cloud Correct:\t\t{cloud_correct}
        Cloud Mistake:\t\t{cloud_mistake}
        Not Cloud Correct:\t{not_cloud_correct}
        Not Cloud Mistake:\t{not_cloud_mistake}
        Rate:\t\t\t{(cloud_correct+not_cloud_correct)/total:.2f}

        """)
    i += 1

# mean_time = np.mean(time_taken)
# mean_fps = 1/mean_time
# print(f"Mean Time: {mean_time: 1.5f} - Mean FPS: {mean_fps:2.5f}")
# Out:
# 1/1 [==============================] - 8s 8s/step
# <PIL.Image.Image image mode=RGB size=1551x384>
#         train_blue/blue_patch_270_13_by_18_LC08_L1TP_045026_20160720_20170221_01_T1.TIF
#         Total:			147456
#         Cloud Correct:		13649
#         Cloud Mistake:		10618
#         Not Cloud Correct:	121726
#         Not Cloud Mistake:	1463
#         Rate:			0.92
#
#
# 1/1 [==============================] - 4s 4s/step
# <PIL.Image.Image image mode=RGB size=1551x384>
#         train_blue/blue_patch_265_13_by_13_LC08_L1TP_029040_20160720_20170222_01_T1.TIF
#         Total:			147456
#         Cloud Correct:		9832
#         Cloud Mistake:		9731
#         Not Cloud Correct:	125751
#         Not Cloud Mistake:	2142
#         Rate:			0.92
#
#
# 1/1 [==============================] - 4s 4s/step
# <PIL.Image.Image image mode=RGB size=1551x384>
#         train_blue/blue_patch_278_14_by_5_LC08_L1TP_045026_20160720_20170221_01_T1.TIF
#         Total:			147456
#         Cloud Correct:		9236
#         Cloud Mistake:		14232
#         Not Cloud Correct:	123566
#         Not Cloud Mistake:	422
#         Rate:			0.90
#
#
# 1/1 [==============================] - 5s 5s/step
# <PIL.Image.Image image mode=RGB size=1551x384>
#         train_blue/blue_patch_266_13_by_14_LC08_L1TP_034034_20160520_20170223_01_T1.TIF
#         Total:			147456
#         Cloud Correct:		33351
#         Cloud Mistake:		10547
#         Not Cloud Correct:	101269
#         Not Cloud Mistake:	2289
#         Rate:			0.91
#
#
# 1/1 [==============================] - 4s 4s/step
# <PIL.Image.Image image mode=RGB size=1551x384>
#         train_blue/blue_patch_266_13_by_14_LC08_L1TP_029040_20160720_20170222_01_T1.TIF
#         Total:			147456
#         Cloud Correct:		18304
#         Cloud Mistake:		14508
#         Not Cloud Correct:	113751
#         Not Cloud Mistake:	893
#         Rate:			0.90
#
#
# 1/1 [==============================] - 6s 6s/step
# <PIL.Image.Image image mode=RGB size=1551x384>
#         train_blue/blue_patch_256_13_by_4_LC08_L1TP_034034_20160520_20170223_01_T1.TIF
#         Total:			147456
#         Cloud Correct:		2058
#         Cloud Mistake:		2008
#         Not Cloud Correct:	129593
#         Not Cloud Mistake:	13797
#         Rate:			0.89
#
#
# 1/1 [==============================] - 4s 4s/step
# <PIL.Image.Image image mode=RGB size=1551x384>
#         train_blue/blue_patch_267_13_by_15_LC08_L1TP_029040_20160720_20170222_01_T1.TIF
#         Total:			147456
#         Cloud Correct:		25012
#         Cloud Mistake:		17343
#         Not Cloud Correct:	103895
#         Not Cloud Mistake:	1206
#         Rate:			0.87
#
#
# 1/1 [==============================] - 5s 5s/step
# <PIL.Image.Image image mode=RGB size=1551x384>
#         train_blue/blue_patch_269_14_by_9_LC08_L1TP_002054_20160520_20170324_01_T1.TIF
#         Total:			147456
#         Cloud Correct:		94596
#         Cloud Mistake:		15235
#         Not Cloud Correct:	36215
#         Not Cloud Mistake:	1410
#         Rate:			0.89
#
#
# 1/1 [==============================] - 4s 4s/step
# <PIL.Image.Image image mode=RGB size=1551x384>
#         train_blue/blue_patch_269_13_by_17_LC08_L1TP_029040_20160720_20170222_01_T1.TIF
#         Total:			147456
#         Cloud Correct:		16608
#         Cloud Mistake:		13926
#         Not Cloud Correct:	113689
#         Not Cloud Mistake:	3233
#         Rate:			0.88
#
#
# 1/1 [==============================] - 4s 4s/step
# <PIL.Image.Image image mode=RGB size=1551x384>
#         train_blue/blue_patch_265_13_by_13_LC08_L1TP_032029_20160420_20170223_01_T1.TIF
#         Total:			147456
#         Cloud Correct:		8624
#         Cloud Mistake:		9298
#         Not Cloud Correct:	121074
#         Not Cloud Mistake:	8460
#         Rate:			0.88

# %% [markdown]
# ## Bad Results

# %%
test_index = [3314, 3620, 5333, 5678, 1033]

blue_test = []
gt_test = []

for i in test_index:
    blue_test.append(train_blue[i])
    gt_test.append(train_gt[i])

# %%
time_taken = []
i = 0
for im in blue_test:
    name = f"{i}.png"
    x = cv2.imread(im, cv2.IMREAD_COLOR)
    x = x/255.0
    x = np.expand_dims(x, axis=0)

    start_time = time.time()
    p = model.predict(x)[0]
    total_time = time.time()-start_time
    time_taken.append(total_time)

    p = p>0.5
    p = p*255.0

    cv2.imwrite(os.path.join(save_path, f"p-{name}"), p)
    b = cv2.imread(train_blue[test_index[i]])
    g = cv2.imread(train_gt[test_index[i]])
    bl = np.concatenate((b,line), axis=1)
    f = np.concatenate((bl,g), axis= 1)
    fl = np.concatenate((f,line), axis= 1)
    p = np.dstack([p,p,p])

    f2 = np.concatenate((fl,p), axis= 1)
    f2l = np.concatenate((f2,line), axis= 1)
    res, cloud_correct, cloud_mistake, not_cloud_correct, not_cloud_mistake = colored_res(g, p)
    final =  np.concatenate((f2l, res), axis= 1)
    final = final[...,::-1].copy()
    cv2_imshow(final)
    print(f"""
        {blue_test[i]}
        Total:\t\t\t{total}
        Cloud Correct:\t\t{cloud_correct}
        Cloud Mistake:\t\t{cloud_mistake}
        Not Cloud Correct:\t{not_cloud_correct}
        Not Cloud Mistake:\t{not_cloud_mistake}
        Rate:\t\t\t{(cloud_correct+not_cloud_correct)/total:.2f}

        """)
    i += 1

# mean_time = np.mean(time_taken)
# mean_fps = 1/mean_time
# print(f"Mean Time: {mean_time: 1.5f} - Mean FPS: {mean_fps:2.5f}")
# Out:
# 1/1 [==============================] - 8s 8s/step
# <PIL.Image.Image image mode=RGB size=1551x384>
#         train_blue/blue_patch_267_12_by_3_LC08_L1TP_011002_20160620_20170323_01_T1.TIF
#         Total:			147456
#         Cloud Correct:		48700
#         Cloud Mistake:		3
#         Not Cloud Correct:	7
#         Not Cloud Mistake:	98746
#         Rate:			0.33
#
#
# 1/1 [==============================] - 4s 4s/step
# <PIL.Image.Image image mode=RGB size=1551x384>
#         train_blue/blue_patch_282_13_by_18_LC08_L1TP_063016_20160920_20170221_01_T1.TIF
#         Total:			147456
#         Cloud Correct:		20330
#         Cloud Mistake:		689
#         Not Cloud Correct:	8043
#         Not Cloud Mistake:	118394
#         Rate:			0.19
#
#
# 1/1 [==============================] - 5s 5s/step
# <PIL.Image.Image image mode=RGB size=1551x384>
#         train_blue/blue_patch_368_17_by_16_LC08_L1TP_064014_20160420_20170223_01_T1.TIF
#         Total:			147456
#         Cloud Correct:		3
#         Cloud Mistake:		10
#         Not Cloud Correct:	59811
#         Not Cloud Mistake:	87632
#         Rate:			0.41
#
#
# 1/1 [==============================] - 4s 4s/step
# <PIL.Image.Image image mode=RGB size=1551x384>
#         train_blue/blue_patch_385_19_by_7_LC08_L1TP_011247_20160620_20170323_01_T1.TIF
#         Total:			147456
#         Cloud Correct:		47732
#         Cloud Mistake:		9880
#         Not Cloud Correct:	10495
#         Not Cloud Mistake:	79349
#         Rate:			0.39
#
#
# 1/1 [==============================] - 4s 4s/step
# <PIL.Image.Image image mode=RGB size=1551x384>
#         train_blue/blue_patch_152_7_by_8_LC08_L1TP_011002_20160620_20170323_01_T1.TIF
#         Total:			147456
#         Cloud Correct:		30178
#         Cloud Mistake:		46741
#         Not Cloud Correct:	35922
#         Not Cloud Mistake:	34615
#         Rate:			0.45
